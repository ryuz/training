# %% [markdown]
# # 1.2.4 ガウス分布

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# 図1.5に出てくる話をサンプル数を変えてやってみる
#
# サンプル数と推定誤差を何となく見た目で体感してみる

# %%
plt.figure(figsize=(12, 8))
x = np.linspace(-5, +5, 100)
for i in range(20):
    n = 2+i
    plt.subplot(4, 5, i+1)
    z = np.zeros((n))
    y = np.random.normal(0, 1, size=n)
    u = np.mean(y)
    s = np.std(y)
    plt.title('n={}'.format(n))
    plt.scatter(y, z, color='green')
    plt.plot(x, norm.pdf(x, 0, 1))
    plt.plot(x, norm.pdf(x, u, s))
plt.tight_layout()

# %%
plt.figure(figsize=(12, 8))
x = np.linspace(-5, +5, 100)
for i in range(20):
    n = 2
    plt.subplot(4, 5, i+1)
    z = np.zeros((n))
    y = np.random.normal(0, 1, size=n)
    u = np.mean(y)
    s = np.std(y)
    plt.title('n={}'.format(n))
    plt.scatter(y, z, color='green')
    plt.plot(x, norm.pdf(x, 0, 1))
    plt.plot(x, norm.pdf(x, u, s))
plt.tight_layout()

# %%
plt.figure(figsize=(12, 8))
x = np.linspace(-5, +5, 100)
for i in range(20):
    n = 3
    plt.subplot(4, 5, i+1)
    z = np.zeros((n))
    y = np.random.normal(0, 1, size=n)
    u = np.mean(y)
    s = np.std(y)
    plt.title('n={}'.format(n))
    plt.scatter(y, z, color='green')
    plt.plot(x, norm.pdf(x, 0, 1))
    plt.plot(x, norm.pdf(x, u, s))
plt.tight_layout()

# %%
plt.figure(figsize=(12, 8))
x = np.linspace(-5, +5, 100)
for i in range(20):
    n = 10
    plt.subplot(4, 5, i+1)
    z = np.zeros((n))
    y = np.random.normal(0, 1, size=n)
    u = np.mean(y)
    s = np.std(y)
    plt.title('n={}'.format(n))
    plt.scatter(y, z, color='green')
    plt.plot(x, norm.pdf(x, 0, 1))
    plt.plot(x, norm.pdf(x, u, s))
plt.tight_layout()

# %%
plt.figure(figsize=(12, 8))
x = np.linspace(-5, +5, 100)
for i in range(20):
    n = 100
    plt.subplot(4, 5, i+1)
    z = np.zeros((n))
    y = np.random.normal(0, 1, size=n)
    u = np.mean(y)
    s = np.std(y)
    plt.title('n={}'.format(n))
    plt.scatter(y, z, color='green')
    plt.plot(x, norm.pdf(x, 0, 1))
    plt.plot(x, norm.pdf(x, u, s))
plt.tight_layout()

# %%
plt.figure(figsize=(12, 8))
x = np.linspace(-5, +5, 100)
for i in range(20):
    n = 1000
    plt.subplot(4, 5, i+1)
    z = np.zeros((n))
    y = np.random.normal(0, 1, size=n)
    u = np.mean(y)
    s = np.std(y)
    plt.title('n={}'.format(n))
    plt.scatter(y, z, color='green')
    plt.plot(x, norm.pdf(x, 0, 1))
    plt.plot(x, norm.pdf(x, u, s))
plt.tight_layout()
